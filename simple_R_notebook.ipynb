# %% [markdown]
# ## Introduction

# %% [markdown]
# This is a simple notebook that I've created.  Nothing fancy (*yet*) but I hope to expand on this in the **coming months**.

# %%
x = rnorm(9e6)
hist(x, main=sprintf('mean %.3f n %d', mean(x), length(x)))
# Out:
# Plot with title “mean -0.001 n 9000000”

# %%
version
# Out:
#                _
# platform       x86_64-apple-darwin11.4.2
# arch           x86_64
# os             darwin11.4.2
# system         x86_64, darwin11.4.2
# status
# major          3
# minor          3.2
# year           2016
# month          10
# day            31
# svn rev        71607
# language       R
# version.string R version 3.3.2 (2016-10-31)
# nickname       Sincere Pumpkin Patch
